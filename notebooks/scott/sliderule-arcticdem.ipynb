# %% [markdown]
# # Get ArticDEM + SlideRule Returns
#
# Difference SlideRule Elevations from ArticDEM

# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import boto3
from sliderule import sliderule, icesat2

# %%
aoi_url = 'https://raw.githubusercontent.com/ICESAT-2HackWeek/dzdt/main/sites/utqiagvik-polygon.geojson'
gfa = gpd.read_file(aoi_url)
gfa.explore(style_kwds=dict(fill=False, color='magenta'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c94187f5963a08cb6f450fe5a1c2ede5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c94187f5963a08cb6f450fe5a1c2ede5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c94187f5963a08cb6f450fe5a1c2ede5 = L.map(
#                 &quot;map_c94187f5963a08cb6f450fe5a1c2ede5&quot;,
#                 {
#                     center: [71.22541839076811, -156.62567522260997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c94187f5963a08cb6f450fe5a1c2ede5);
#
#
#
#
#
#             var tile_layer_3562bc7bccb34c974d52f4e152d1ae84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c94187f5963a08cb6f450fe5a1c2ede5);
#
#
#             map_c94187f5963a08cb6f450fe5a1c2ede5.fitBounds(
#                 [[71.11303515926326, -156.98688849401648], [71.33780162227296, -156.26446195120343]],
#                 {}
#             );
#
#
#         function geo_json_a9c9b998f7039540643bf12b03c6b1d1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;magenta&quot;, &quot;fill&quot;: false, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a9c9b998f7039540643bf12b03c6b1d1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a9c9b998f7039540643bf12b03c6b1d1_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a9c9b998f7039540643bf12b03c6b1d1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a9c9b998f7039540643bf12b03c6b1d1_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a9c9b998f7039540643bf12b03c6b1d1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a9c9b998f7039540643bf12b03c6b1d1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a9c9b998f7039540643bf12b03c6b1d1 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9c9b998f7039540643bf12b03c6b1d1_onEachFeature,
#
#                 style: geo_json_a9c9b998f7039540643bf12b03c6b1d1_styler,
#                 pointToLayer: geo_json_a9c9b998f7039540643bf12b03c6b1d1_pointToLayer
#         });
#
#         function geo_json_a9c9b998f7039540643bf12b03c6b1d1_add (data) {
#             geo_json_a9c9b998f7039540643bf12b03c6b1d1
#                 .addData(data)
#                 .addTo(map_c94187f5963a08cb6f450fe5a1c2ede5);
#         }
#             geo_json_a9c9b998f7039540643bf12b03c6b1d1_add({&quot;bbox&quot;: [-156.98688849401648, 71.11303515926326, -156.26446195120343, 71.33780162227296], &quot;features&quot;: [{&quot;bbox&quot;: [-156.98688849401648, 71.11303515926326, -156.26446195120343, 71.33780162227296], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-156.98688849401648, 71.21627954209416], [-156.6430455278934, 71.11303515926326], [-156.26446195120343, 71.27727860723829], [-156.7080728245955, 71.33780162227296], [-156.98688849401648, 71.21627954209416]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties

# %% [markdown]
# ## SlideRule Setup

# %%
icesat2.init("slideruleearth.io", verbose=False)

# %%
# Start with all defaults, just Polygon
parms = {
    "poly": sliderule.toregion(gfa)["poly"],
    # "srt": icesat2.SRT_LAND,
    # "cnf": icesat2.CNF_SURFACE_HIGH,
    # "len": 40.0,
    # "res": 20.0,
    # "maxi": 6
    "t0": "2023-01-01T00:00:00Z",
    "t1": "2024-01-01T00:00:00Z",
}

# %%
# Add Raster Sampling
# https://www.slideruleearth.io/web/rtd/user_guide/GeoRaster.html
parms["samples"] = {
            # "hls": {"asset": "landsat-hls", "bands": ["NDSI"]},
            "mosaic": {"asset": "arcticdem-mosaic", "algorithm":"NearestNeighbour"},
            #"mosaic": {"asset": "arcticdem-mosaic", "radius": 10.0, "zonal_stats": True},
            #"strips": {"asset": "arcticdem-strips", "algorithm": "CubicSpline"}
        }

# %%
# NOTE: don't do this for raster samples

# # Output to S3
# S3_OUTPUT = 's3://nasa-cryo-scratch/dzdt/utiaqvik.parquet'

# # Get CryoCloud AWS Credentials for SlideRule
# client = boto3.client('sts')

# with open(os.environ['AWS_WEB_IDENTITY_TOKEN_FILE']) as f:
#     TOKEN = f.read()

# response = client.assume_role_with_web_identity(
#     RoleArn=os.environ['AWS_ROLE_ARN'],
#     RoleSessionName=os.environ['JUPYTERHUB_CLIENT_ID'],
#     WebIdentityToken=TOKEN,
#     DurationSeconds=3600
# )


# # Update SlideRule Parameters
# parms["output"] = {
#     "path": S3_OUTPUT, 
#     "format": "parquet", 
#     "open_on_complete": False,
#     "region": "us-west-2",
#     "credentials": {
#          "aws_access_key_id": response['Credentials']['AccessKeyId'],
#          "aws_secret_access_key": response['Credentials']['SecretAccessKey'],
#          "aws_session_token": response['Credentials']['SessionToken']
#      }
# }

# %% [markdown]
# ## Run SlideRule

# %%
# Check your parameters before submitting
parms
# Out:
# {'poly': [{'lon': -156.6430455278934, 'lat': 71.11303515926326},
#   {'lon': -156.26446195120343, 'lat': 71.27727860723829},
#   {'lon': -156.7080728245955, 'lat': 71.33780162227296},
#   {'lon': -156.98688849401648, 'lat': 71.21627954209416},
#   {'lon': -156.6430455278934, 'lat': 71.11303515926326}],
#  't0': '2023-01-01T00:00:00Z',
#  't1': '2024-01-01T00:00:00Z',
#  'samples': {'mosaic': {'asset': 'arcticdem-mosaic',
#    'algorithm': 'NearestNeighbour'}}}

# %%
# %%time

# Run SlideRule

gf = icesat2.atl06p(parms, version='006')

print("Start:", gf.index.min().strftime('%Y-%m-%d'))
print("End:", gf.index.max().strftime('%Y-%m-%d'))
print("Reference Ground Tracks: {}".format(gf["rgt"].unique()))
print("Cycles: {}".format(gf["cycle"].unique()))
print("Elevation Measurements: {} ".format(gf.shape[0]))
gf.head(2)
# Out:
# Start: 2023-01-09
# End: 2023-04-15
# Reference Ground Tracks: [ 312  373  823 1257 1265 1326  381]
# Cycles: [18 19]
# Elevation Measurements: 16591
# CPU times: user 1.13 s, sys: 37.9 ms, total: 1.17 s
# Wall time: 59 s
#                                rms_misfit  gt  dh_fit_dy  n_fit_photons  \
# time
# 2023-01-09 23:39:51.181383424    0.134553  20        0.0             10
# 2023-01-09 23:39:51.184223232    0.000000  20        0.0             13
#
#                                    distance  w_surface_window_final  pflags  \
# time
# 2023-01-09 23:39:51.181383424  7.947966e+06               17.779561       0
# 2023-01-09 23:39:51.184223232  7.947986e+06               54.940145       2
#
#                                dh_fit_dx  cycle     h_mean   h_sigma  spot  \
# time
# 2023-01-09 23:39:51.181383424  -0.004885     18   1.625571  0.050964     5
# 2023-01-09 23:39:51.184223232  -2.154382     18 -28.113643  0.000000     5
#
#                                segment_id  rgt                     geometry  \
# time
# 2023-01-09 23:39:51.181383424      396540  312  POINT (-156.36948 71.24078)
# 2023-01-09 23:39:51.184223232      396541  312  POINT (-156.36956 71.24096)
#
#                                mosaic.time  mosaic.file_id  mosaic.value  \
# time
# 2023-01-09 23:39:51.181383424          NaN             NaN           NaN
# 2023-01-09 23:39:51.184223232          NaN             NaN           NaN
#
#                                mosaic.flags
# time
# 2023-01-09 23:39:51.181383424           NaN
# 2023-01-09 23:39:51.184223232           NaN

# %%
output_file = 'utqiagvik.gpkg'
gf.to_file(output_file)

# %% [markdown]
# ## Analyze SlideRule Results

# %%
output_file = 'utqiagvik.gpkg'
#gf = gpd.read_parquet(s3path)
gf = gpd.read_file(output_file)

# %%
len(gf)
# Out:
# 16591

# %%
gf.head()
# Out:
#                      time  rms_misfit  gt  dh_fit_dy  n_fit_photons  \
# 0 2023-01-09 23:39:51.181    0.134553  20        0.0             10
# 1 2023-01-09 23:39:51.184    0.000000  20        0.0             13
# 2 2023-01-09 23:39:51.187    0.000000  20        0.0             10
# 3 2023-01-09 23:39:51.697    0.000000  20        0.0             10
# 4 2023-01-13 23:31:33.621    0.505195  50        0.0             58
#
#        distance  w_surface_window_final  pflags  dh_fit_dx  cycle     h_mean  \
# 0  7.947966e+06               17.779561       0  -0.004885     18   1.625571
# 1  7.947986e+06               54.940145       2  -2.154382     18 -28.113643
# 2  7.948006e+06               57.283934       2   2.246301     18 -25.295689
# 3  7.951628e+06              291.900461       2  11.447052     18   2.851770
# 4  7.943253e+06               13.065198       0  -0.006597     18  10.703961
#
#     h_sigma  spot  segment_id  rgt  mosaic.time  mosaic.file_id  mosaic.value  \
# 0  0.050964     5      396540  312          NaN             NaN           NaN
# 1  0.000000     5      396541  312          NaN             NaN           NaN
# 2  0.000000     5      396542  312          NaN             NaN           NaN
# 3  0.000000     5      396723  312          NaN             NaN           NaN
# 4  0.066336     2      396305  373          NaN             NaN           NaN
#
#    mosaic.flags                     geometry
# 0           NaN  POINT (-156.36948 71.24078)
# 1           NaN  POINT (-156.36956 71.24096)
# 2           NaN  POINT (-156.36963 71.24113)
# 3           NaN  POINT (-156.38271 71.27333)
# 4           NaN  POINT (-156.95342 71.20634)

# %%
gf['mosaic.value'].describe()
# Out:
# count    537.000000
# mean       0.807525
# std        1.944718
# min       -1.418108
# 25%       -0.926480
# 50%       -0.400521
# 75%        2.791387
# max        6.903812
# Name: mosaic.value, dtype: float64

# %% [markdown]
# ### Difference Sliderule Elevation - ArcticDEM elevation

# %%
gfa = gpd.read_file(aoi_url)
m = gfa.explore(style_kwds=dict(fill=False, color='magenta')) 

points = gf.sample(1000).reset_index()
points['time'] = points.time.dt.strftime('%Y-%m-%d')
points.explore(column='h_mean', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93674ab3407b07a976a13641e34fd15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93674ab3407b07a976a13641e34fd15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93674ab3407b07a976a13641e34fd15a = L.map(
#                 &quot;map_93674ab3407b07a976a13641e34fd15a&quot;,
#                 {
#                     center: [71.22541839076811, -156.62567522260997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_93674ab3407b07a976a13641e34fd15a);
#
#
#
#
#
#             var tile_layer_53b24d6fa8afb74a8c4f06b838987969 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93674ab3407b07a976a13641e34fd15a);
#
#
#             map_93674ab3407b07a976a13641e34fd15a.fitBounds(
#                 [[71.11303515926326, -156.98688849401648], [71.33780162227296, -156.26446195120343]],
#                 {}
#             );
#
#
#         function geo_json_2f7573b0bde08fe822942bb14b4d8014_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;magenta&quot;, &quot;fill&quot;: false, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2f7573b0bde08fe822942bb14b4d8014_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2f7573b0bde08fe822942bb14b4d8014_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_2f7573b0bde08fe822942bb14b4d8014_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2f7573b0bde08fe822942bb14b4d8014_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_2f7573b0bde08fe822942bb14b4d8014.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2f7573b0bde08fe822942bb14b4d8014_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2f7573b0bde08fe822942bb14b4d8014 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f7573b0bde08fe822942bb14b4d8014_onEachFeature,
#
#                 style: geo_json_2f7573b0bde08fe822942bb14b4d8014_styler,
#                 pointToLayer: geo_json_2f7573b0bde08fe822942bb14b4d8014_pointToLayer
#         });
#
#         function geo_json_2f7573b0bde08fe822942bb14b4d8014_add (data) {
#             geo_json_2f7573b0bde08fe822942bb14b4d8014
#                 .addData(data)
#                 .addTo(map_93674ab3407b07a976a13641e

# %%
m = gfa.explore(style_kwds=dict(fill=False, color='magenta')) 
points = gf.dropna().reset_index()
points['time'] = points.time.dt.strftime('%Y-%m-%d')
points.explore(column='mosaic.value',m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ad36b9ea1f6f71044a4a7cb9db5083d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ad36b9ea1f6f71044a4a7cb9db5083d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ad36b9ea1f6f71044a4a7cb9db5083d = L.map(
#                 &quot;map_3ad36b9ea1f6f71044a4a7cb9db5083d&quot;,
#                 {
#                     center: [71.22541839076811, -156.62567522260997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3ad36b9ea1f6f71044a4a7cb9db5083d);
#
#
#
#
#
#             var tile_layer_a6cd24cf9ba0f06f35371a1b45edc2ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ad36b9ea1f6f71044a4a7cb9db5083d);
#
#
#             map_3ad36b9ea1f6f71044a4a7cb9db5083d.fitBounds(
#                 [[71.11303515926326, -156.98688849401648], [71.33780162227296, -156.26446195120343]],
#                 {}
#             );
#
#
#         function geo_json_6f1af2d49592d0be83399036d6a27edb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;magenta&quot;, &quot;fill&quot;: false, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6f1af2d49592d0be83399036d6a27edb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6f1af2d49592d0be83399036d6a27edb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6f1af2d49592d0be83399036d6a27edb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6f1af2d49592d0be83399036d6a27edb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6f1af2d49592d0be83399036d6a27edb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6f1af2d49592d0be83399036d6a27edb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6f1af2d49592d0be83399036d6a27edb = L.geoJson(null, {
#                 onEachFeature: geo_json_6f1af2d49592d0be83399036d6a27edb_onEachFeature,
#
#                 style: geo_json_6f1af2d49592d0be83399036d6a27edb_styler,
#                 pointToLayer: geo_json_6f1af2d49592d0be83399036d6a27edb_pointToLayer
#         });
#
#         function geo_json_6f1af2d49592d0be83399036d6a27edb_add (data) {
#             geo_json_6f1af2d49592d0be83399036d6a27edb
#                 .addData(data)
#                 .addTo(map_3ad36b9ea1f6f71044a4a7cb9
